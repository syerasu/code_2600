# %%
# packages
import os
import joblib
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import subplots
import statsmodels.api as sm
from sklearn.model_selection import train_test_split 
from sklearn.ensemble import GradientBoostingRegressor as GBR
from sklearn.model_selection import GridSearchCV

# set seed
seed = 5151

# %% [markdown]
# ### You'll need the California housing data (CAhousing.csv) to complete this exercise. Your goal is to predict the median house value.

# %%
CAhousing = pd.read_csv('data/CAhousing.csv')
CAhousing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -120.45     34.66                 7.0       3329.0           504.0
# 1    -114.64     34.83                10.0       2502.0           573.0
# 2    -117.24     32.74                43.0       2216.0           375.0
# 3    -122.43     37.76                52.0       3771.0          1017.0
# 4    -118.02     34.13                34.0       1966.0           319.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0      1462.0       452.0         4.7875            198300.0      NEAR OCEAN
# 1      1152.0       481.0         1.7062             86800.0          INLAND
# 2       918.0       388.0         5.5289            297700.0      NEAR OCEAN
# 3      1575.0       921.0         3.5655            427300.0        NEAR BAY
# 4       980.0       297.0         7.7307            429000.0          INLAND

# %%
CAhousing.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
CAhousing.shape
# Out:
# (15480, 10)

# %% [markdown]
# ### There is a single categorical variable in this dataset that we will convert to a series of binary variables.

# %%
CAhousing['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     6857
# INLAND        4933
# NEAR OCEAN    1974
# NEAR BAY      1712
# ISLAND           4
# Name: count, dtype: int64

# %%
# create binary variables for levels which have enough records, using '<1H OCEAN' as base.
CAhousing['ocean_prox_inland'] = (CAhousing.ocean_proximity == 'INLAND').astype(int)
CAhousing['ocean_prox_nearocean'] = (CAhousing.ocean_proximity == 'NEAR OCEAN').astype(int)
CAhousing['ocean_prox_nearbay'] = (CAhousing.ocean_proximity == 'NEAR BAY').astype(int)

# check for intended outcome
print(CAhousing['ocean_prox_inland'].value_counts())
print(CAhousing['ocean_prox_nearocean'].value_counts())
print(CAhousing['ocean_prox_nearbay'].value_counts())
# Out:
# ocean_prox_inland
# 0    10547
# 1     4933
# Name: count, dtype: int64
# ocean_prox_nearocean
# 0    13506
# 1     1974
# Name: count, dtype: int64
# ocean_prox_nearbay
# 0    13768
# 1     1712
# Name: count, dtype: int64

# %%
indep_vars = ['longitude', 'latitude', 'housing_median_age', 'total_rooms', 
              'total_bedrooms', 'population', 'households', 'median_income', 
              'ocean_prox_inland', 'ocean_prox_nearocean', 'ocean_prox_nearbay']

X = CAhousing[indep_vars]
y = CAhousing['median_house_value']

# %%
X_train, X_test, y_train, y_test, Train, Test = train_test_split(X, y, CAhousing, 
                                                                 random_state = seed, 
                                                                 test_size = 0.33, 
                                                                 shuffle = True)

# %%
X_train.corr().style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style type="text/css">
# #T_f736b_row0_col0, #T_f736b_row1_col1, #T_f736b_row2_col2, #T_f736b_row3_col3, #T_f736b_row4_col4, #T_f736b_row5_col5, #T_f736b_row6_col6, #T_f736b_row7_col7, #T_f736b_row8_col8, #T_f736b_row9_col9, #T_f736b_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f736b_row0_col1, #T_f736b_row1_col0 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_f736b_row0_col2, #T_f736b_row2_col0 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_f736b_row0_col3, #T_f736b_row3_col0 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_f736b_row0_col4, #T_f736b_row4_col0 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_f736b_row0_col5, #T_f736b_row5_col0 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_f736b_row0_col6, #T_f736b_row6_col0, #T_f736b_row7_col10, #T_f736b_row10_col7 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_f736b_row0_col7, #T_f736b_row3_col9, #T_f736b_row7_col0, #T_f736b_row9_col3 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_f736b_row0_col8, #T_f736b_row1_col4, #T_f736b_row4_col1, #T_f736b_row5_col10, #T_f736b_row8_col0, #T_f736b_row10_col5 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_f736b_row0_col9, #T_f736b_row9_col0 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_f736b_row0_col10, #T_f736b_row10_col0 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_f736b_row1_col2, #T_f736b_row2_col1, #T_f736b_row2_col9, #T_f736b_row3_col8, #T_f736b_row8_col3, #T_f736b_row9_col2 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_f736b_row1_col3, #T_f736b_row3_col1 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_f736b_row1_col5, #T_f736b_row5_col1 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_f736b_row1_col6, #T_f736b_row6_col1 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_f736b_row1_col7, #T_f736b_row7_col1 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_f736b_row1_col8, #T_f736b_row8_col1 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_f736b_row1_col9, #T_f736b_row9_col1 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_f736b_row1_col10, #T_f736b_row10_col1 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_f736b_row2_col3, #T_f736b_row3_col2 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_f736b_row2_col4, #T_f736b_row4_col2 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_f736b_row2_col5, #T_f736b_row5_col2 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_f736b_row2_col6, #T_f736b_row6_col2 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_f736b_row2_col7, #T_f736b_row7_col2, #T_f736b_row9_col10, #T_f736b_row10_col9 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_f736b_row2_col8, #T_f736b_row7_col8, #T_f736b_row8_col2, #T_f736b_row8_col7 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_f736b_row2_col10, #T_f736b_row10_col2 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_f736b_row3_col4, #T_f736b_row4_col3 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_f736b_row3_col5, #T_f736b_row5_col3 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_f736b_row3_col6, #T_f736b_row6_col3 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_f736b_row3_col7, #T_f736b_row7_col3 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_f736b_row3_col10, #T_f736b_row5_col8, #T_f736b_row8_col5, #T_f736b_row10_col3 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_f736b_row4_col5, #T_f736b_row5_col4 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_f736b_row4_col6, #T_f736b_row6_col4 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_f736b_row4_col7, #T_f736b_row4_col8, #T_f736b_row5_col9, #T_f736b_row7_col4, #T_f736b_row8_col4, #T_f736b_row9_col5 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_f736b_row4_col9, #T_f736b_row5_col7, #T_f736b_row6_col9, #T_f736b_row7_col5, #T_f736b_row9_col4, #T_f736b_row9_col6 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_f736b_row4_col10, #T_f736b_row6_col10, #T_f736b_row10_col4, #T_f736b_row10_col6 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_f736b_row5_col6, #T_f736b_row6_col5 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_f736b_row6_col7, #T_f736b_row7_col6 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_f736b_row6_col8, #T_f736b_row8_col6 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_f736b_row7_col9, #T_f736b_row9_col7 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_f736b_row8_col9, #T_f736b_row9_col8 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_f736b_row8_col10, #T_f736b_row10_col8 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# </style>
# <table id="T_f736b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f736b_level0_col0" class="col_heading level0 col0" >longitude</th>
#       <th id="T_f736b_level0_col1" class="col_heading level0 col1" >latitude</th>
#       <th id="T_f736b_level0_col2" class="col_heading level0 col2" >housing_median_age</th>
#       <th id="T_f736b_level0_col3" class="col_heading level0 col3" >total_rooms</th>
#       <th id="T_f736b_level0_col4" class="col_heading level0 col4" >total_bedrooms</th>
#       <th id="T_f736b_level0_col5" class="col_heading level0 col5" >population</th>
#       <th id="T_f736b_level0_col6" class="col_heading level0 col6" >households</th>
#       <th id="T_f736b_level0_col7" class="col_heading level0 col7" >median_income</th>
#       <th id="T_f736b_level0_col8" class="col_heading level0 col8" >ocean_prox_inland</th>
#       <th id="T_f736b_level0_col9" class="col_heading level0 col9" >ocean_prox_nearocean</th>
#       <th id="T_f736b_level0_col10" class="col_heading level0 col10" >ocean_prox_nearbay</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f736b_level0_row0" class="row_heading level0 row0" >longitude</th>
#       <td id="T_f736b_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_f736b_row0_col1" class="data row0 col1" >-0.924779</td>
#       <td id="T_f736b_row0_col2" class="data row0 col2" >-0.118552</td>
#       <td id="T_f736b_row0_col3" class="data row0 col3" >0.044445</td>
#       <td id="T_f736b_row0_col4" class="data row0 col4" >0.067878</td>
#       <td id="T_f736b_row0_col5" class="data row0 col5" >0.095517</td>
#       <td id="T_f736b_row0_col6" class="data row0 col6" >0.056249</td>
#       <td id="T_f736b_row0_col7" class="data row0 col7" >-0.001915</td>
#       <td id="T_f736b_row0_col8" class="data row0 col8" >-0.068406</td>
#       <td id="T_f736b_row0_col9" class="data row0 col9" >0.047632</td>
#       <td id="T_f736b_row0_col10" class="data row0 col10" >-0.471177</td>
#     </tr>
#     <tr>
#       <th id="T_f736b_level0_row1" class="row_heading level0 row1" >latitude</th>
#       <td id="T_f736b_row1_col0" class="data row1 col0" >-0.924779</td>
#       <td id="T_f736b_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_f736b_row1_col2" class="data row1 col2" >0.017276</td>
#       <td id="T_f736b_row1_col3" class="data row1 col3" >-0.034301</td>
#       <td id="T_f736b_row1_col4" class="data row1 col4" >-0.064393</td>
#       <td id="T_f736b_row1_col5" class="data row1 col5" >-0.104774</td>
#       <td id="T_f736b_row1_col6" class="data row1 col6" >-0.070660</td>
#       <td id="T_f736b_row1_col7" class="data row1 col7" >-0.091395</td>
#       <td id="T_f736b_row1_col8" class="data row1 col8" >0.362431</td>
#       <td id="T_f736b_row1_col9" class="data row1 col9" >-0.162865</td>
#       <td id="T_f736b_row1_col10" class="data row1 col10" >0.352288</td>
#     </tr>
#     <tr>
#       <th id="T_f736b_level0_row2" class="row_heading level0 row2" >housing_median_age</th>
#       <td id="T_f736b_row2_col0" class="data row2 col0" >-0.118552</td>
#       <td id="T_f736b_row2_col1" class="data row2 col1" >0.017276</td>
#       <td id="T_f736b_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_f736b_row2_col3" class="data row2 col3" >-0.356225</td>
#       <td id="T_f736b_row2_col4" class="data row2 col4" >-0.312179</td>
#       <td id="T_f736b_row2_col5" class="data row2 col5" >-0.296755</td>
#       <td id="T_f736b_row2_col6" c

# %%
Train.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  10371.000000  10371.000000        10371.000000  10371.000000
# mean    -119.576317     35.648347           28.707646   2631.445569
# std        1.997211      2.140070           12.631120   2173.616930
# min     -124.260000     32.560000            1.000000      8.000000
# 25%     -121.770000     33.940000           18.000000   1454.000000
# 50%     -118.510000     34.260000           29.000000   2126.000000
# 75%     -118.020000     37.730000           37.000000   3127.000000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    10257.000000  10371.000000  10371.000000   10371.000000
# mean       537.541484   1426.518851    500.422524       3.868065
# std        425.582759   1137.463225    388.555637       1.885826
# min          1.000000      5.000000      1.000000       0.499900
# 25%        296.000000    791.000000    282.000000       2.556800
# 50%        435.000000   1163.000000    410.000000       3.534500
# 75%        640.000000   1719.000000    601.000000       4.747400
# max       6445.000000  28566.000000   6082.000000      15.000100
#
#        median_house_value  ocean_prox_inland  ocean_prox_nearocean  \
# count        10371.000000       10371.000000          10371.000000
# mean        206399.612284           0.323787              0.124771
# std         115215.425942           0.467943              0.330475
# min          14999.000000           0.000000              0.000000
# 25%         118750.000000           0.000000              0.000000
# 50%         179800.000000           0.000000              0.000000
# 75%         264000.000000           1.000000              0.000000
# max         500001.000000           1.000000              1.000000
#
#        ocean_prox_nearbay
# count        10371.000000
# mean             0.109247
# std              0.311964
# min              0.000000
# 25%              0.000000
# 50%              0.000000
# 75%              0.000000
# max              1.000000

# %% [markdown]
# ### We see that `total_bedrooms` has a few missing values, and it is also very correlated with `total_rooms`. Because of this, it's easiest to remove it from our training set.

# %%
indep_vars.remove("total_bedrooms")

# %% [markdown]
# ### We'll define some helper functions here:
# (1) to calculate MSE, and
# (2) to display the improvement of a GBM on test data as additional trees are constructed.

# %%
def mse(y, y_hat):
    """
    Calculate the MSE of a model given actual and predicted values
    """
    # calculate the residual error for each individual record
    resid = y - y_hat
    # square the residual (hence "squared error")
    sq_resid = resid**2
    # calculate the sum of squared errors
    SSR = sum(sq_resid)
    # divide by the number of records to get the mean squared error
    MSE = SSR / y.shape[0]
    return MSE

def gbm_progress(model_name, X_test, y_test):
    """
    Plot the 'progress' of a GBM on a test set to assess robustness
    """
    test_error = np.zeros_like(model_name.train_score_)
    for idx, y_ in enumerate(model_name.staged_predict(X_test)):
        test_error[idx] = np.mean((y_test - y_)**2)

    plot_idx = np.arange(model_name.train_score_.shape[0])
    ax = subplots(figsize=(8,8))[1]
    ax.plot(plot_idx,
            model_name.train_score_,
            'b',
            label='Training')
    ax.plot(plot_idx,
            test_error,
            'r',
            label='Test')
    ax.legend();

# %% [markdown]
# ### Build a basic GBM first.

# %%
# Documentation: https://scikit-learn.org/dev/modules/generated/sklearn.ensemble.GradientBoostingRegressor.html

gbm_basic = GBR(learning_rate=0.1,
               n_estimators=250,
               max_depth=10,
               min_samples_split=2,
               subsample=1,
               random_state=seed)

gbm_basic.fit(X_train[indep_vars], y_train)
# Out:
# GradientBoostingRegressor(max_depth=10, n_estimators=250, random_state=5151,
#                           subsample=1)

# %%
y_hat_basic = gbm_basic.predict(X_test[indep_vars])

mse_basic = mse(y_test, y_hat_basic)
print('test mse: ',mse_basic)
# Out:
# test mse:  2522992630.270553

# %% [markdown]
# ### When we plot the performance of the model on training and test data, we see that performance no longer improves after a certain number of trees (in this case, between 50-100 trees).

# %%
gbm_progress(gbm_basic, X_test[indep_vars], y_test)

# %% [markdown]
# ### Now you'll have the chance to choose optimal hyperparameters to build a better GBM.
# Once the candidate hyperparameters are chosen, use 5-fold cross-validation to decide which collection of hyperparameters are best.

# %%
def get_best_gbm(X, y, results_path="gridsearch_results.pkl", force_retrain=False):
    """
    Runs GridSearchCV OR loads precomputed results if available.

    Parameters:
        X, y : training data
        results_path : where results are saved
        force_retrain : if True, ignore saved file and rerun

    Returns:
        best_model : fitted model
        best_params : dict
    """

    # Fast Version: load existing results
    if os.path.exists(results_path) and not force_retrain:
        data = joblib.load(results_path)
        print("Loaded precomputed GridSearchCV results.")
        return data["best_model"], data["best_params"]

    # Slow Version: run grid search via cross-validation
    print("Running GridSearchCV...")

    ## Define model
    gbm_cv = GBR(random_state=seed)

    ## Define hyperparameter grid. Choose between 1 and 4 values to test for each one.
    #fillin
    param_grid = {
        "n_estimators": [500, 1000],
        "learning_rate": [0.01, 0.1],
        "max_depth": [3, 5],
        "min_samples_leaf": [1, 5],
        "subsample": [0.8, 1.0]
    }

    grid_search = GridSearchCV(
        estimator=gbm_cv,
        param_grid=param_grid,
        cv=5,                               # number of folds
        scoring="neg_mean_squared_error",   # how we evaluate which model is best
        n_jobs=-1,                          # use all available cores
        verbose=3
    )

    grid_search.fit(X, y)

    best_model = grid_search.best_estimator_
    best_params = grid_search.best_params_

    ## Save results. Gradescope will use this file instead of rerunning the grid search.
    joblib.dump({
        "best_model": best_model,
        "best_params": best_params,
        "cv_results": grid_search.cv_results_
    }, results_path)

    print(f"Saved results to {results_path}")

    return best_model, best_params

# %%
# Identify best model
best_model, best_params = get_best_gbm(X_train[indep_vars], y_train, force_retrain=False)

print("Best parameters:")
print(best_params)
# Out:
# Running GridSearchCV...
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=500, subsample=0.8;, score=-3853043214.789 total time=   5.8s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=500, subsample=0.8;, score=-3822474356.114 total time=   5.8s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=500, subsample=0.8;, score=-3973597043.019 total time=   5.8s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=500, subsample=0.8;, score=-3535918196.406 total time=   5.9s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=500, subsample=0.8;, score=-3702499295.413 total time=   6.1s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=500, subsample=1.0;, score=-3893466842.008 total time=   6.9s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=500, subsample=1.0;, score=-4025649931.839 total time=   7.0s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=500, subsample=1.0;, score=-3570475154.172 total time=   7.0s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=500, subsample=1.0;, score=-3777867679.666 total time=   6.7s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=500, subsample=1.0;, score=-3850549334.092 total time=   6.7s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=1000, subsample=0.8;, score=-3317939984.204 total time=  10.9s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=1000, subsample=0.8;, score=-2913098477.170 total time=  11.0s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=1000, subsample=0.8;, score=-3092779058.376 total time=  11.0s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=1000, subsample=0.8;, score=-3182819629.109 total time=  10.9s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=1000, subsample=0.8;, score=-3084535605.367 total time=  11.0s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=1000, subsample=1.0;, score=-3344505550.282 total time=  12.9s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=5, n_estimators=500, subsample=0.8;, score=-3978643813.531 total time=   5.2s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=5, n_estimators=500, subsample=0.8;, score=-3522959536.327 total time=   5.3s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=5, n_estimators=500, subsample=0.8;, score=-3845631952.547 total time=   5.3s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=1000, subsample=1.0;, score=-2954608232.395 total time=  12.5s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=5, n_estimators=500, subsample=0.8;, score=-3812470788.758 total time=   5.3s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=1000, subsample=1.0;, score=-3140148700.038 total time=  12.6s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=5, n_estimators=500, subsample=0.8;, score=-3670691883.399 total time=   5.2s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=5, n_estimators=500, subsample=1.0;, score=-4015846503.914 total time=   6.3s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=1000, subsample=1.0;, score=-3132947846.905 total time=  12.5s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=1000, subsample=1.0;, score=-3184184791.838 total time=  12.7s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=5, n_estimators=500, subsample=1.0;, score=-3566926258.897 total time=   6.4s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=5, n_estimators=500, subsample=1.0;, score=-3857486914.533 total time=   6.5s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=5, n_estimators=500, subsample=1.0;, score=-3869362606.864 total time=   6.6s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=5, n_estimators=500, subsample=1.0;, score=-3759268199.672 total time=   6.6s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=5, n_estimators=1000, subsample=0.8;, score=-3317664894.604 total time=  11.8s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=5, n_estimators=1000, subsample=0.8;, score=-2922680197.083 total time=  12.2s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=5, n_estimators=1000, subsample=0.8;, score=-3206294420.826 total time=  12.2s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=5, n_estimators=1000, subsample=0.8;, score=-3086254256.399 total time=  12.3s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=5, n_estimators=1000, subsample=0.8;, score=-3064352286.450 total time=  12.2s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=5, n_estimators=1000, subsample=1.0;, score=-3345827557.176 total time=  14.4s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=5, n_estimators=1000, subsample=1.0;, score=-2960930792.781 total time=  14.5s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=5, n_estimators=1000, subsample=1.0;, score=-3144016926.241 total time=  14.6s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=500, subsample=0.8;, score=-3059696912.196 total time=   9.3s
# [CV 2/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=500, subsample=0.8;, score=-2787756919.519 total time=   9.4s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=500, subsample=0.8;, score=-2889357834.395 total time=   9.4s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=5, n_estimators=1000, subsample=1.0;, score=-3196425400.768 total time=  14.1s
# [CV 4/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=500, subsample=0.8;, score=-2935160906.357 total time=   9.2s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=5, n_estimators=1000, subsample=1.0;, score=-3050597512.596 total time=  13.7s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=500, subsample=0.8;, score=-2836059477.283 total time=   9.3s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=500, subsample=1.0;, score=-3066200079.237 total time=  11.2s
# [CV 2/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=500, subsample=1.0;, score=-2817386037.341 total time=  11.7s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=500, subsample=1.0;, score=-2952241001.077 total time=  11.6s
# [CV 4/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=500, subsample=1.0;, score=-2969669833.185 total time=  11.6s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=500, subsample=1.0;, score=-2962206701.802 total time=  12.2s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=1000, subsample=0.8;, score=-2694645962.080 total time=  19.9s
# [CV 2/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=1000, subsample=0.8;, score=-2499935412.845 total time=  20.1s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=1000, subsample=0.8;, score=-2438738568.830 total time=  20.3s
# [CV 4/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=1000, subsample=0.8;, score=-2542906997.030 total time=  20.2s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=1000, subsample=0.8;, score=-2498468402.485 total time=  19.2s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=5, n_estimators=500, subsample=0.8;, score=-3034286626.626 total time=   8.8s
# [CV 2/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=1000, subsample=1.0;, score=-2518207270.239 total time=  22.9s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=1000, subsample=1.0;, score=-2713747155.352 total time=  23.1s
# [CV 2/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=5, n_estimators=500, subsample=0.8;, score=-2778603952.822 total time=   9.1s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=1000, subsample=1.0;, score=-2523743621.131 total time=  22.5s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=5, n_estimators=500, subsample=0.8;, score=-2858740604.273 total time=   9.4s
# [CV 4/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=5, n_estimators=500, subsample=0.8;, score=-2917630093.785 total time=   9.2s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=5, n_estimators=500, subsample=0.8;, score=-2856181588.150 total time=   9.1s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=5, n_estimators=500, subsample=1.0;, score=-3050850481.310 total time=  10.8s
# [CV 4/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=1000, subsample=1.0;, score=-2581627588.603 total time=  21.7s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=1000, subsample=1.0;, score=-2578247639.677 total time=  21.8s
# [CV 2/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=5, n_estimators=500, subsample=1.0;, score=-2810866874.736 total time=  10.6s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=5, n_estimators=500, subsample=1.0;, score=-2867567775.499 total time=  11.2s
# [CV 4/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=5, n_estimators=500, subsample=1.0;, score=-2939819709.133 total time=  11.5s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=5, n_estimators=500, subsample=1.0;, score=-2962210777.144 total time=  11.8s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=5, n_estimators=1000, subsample=0.8;, score=-2666649714.985 total time=  19.7s
# [CV 2/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=5, n_estimators=1000, subsample=0.8;, score=-2501742838.735 total time=  19.5s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=5, n_estimators=1000, subsample=0.8;, score=-2422076512.883 total time=  19.8s
# [CV 4/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=5, n_estimators=1000, subsample=0.8;, score=-2553375222.844 total time=  19.7s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=5, n_estimators=1000, subsample=0.8;, score=-2508459933.022 total time=  19.8s
# [CV 1/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=500, subsample=0.8;, score=-2644326501.064 total time=   5.9s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=5, n_estimators=1000, subsample=1.0;, score=-2708599352.727 total time=  23.4s
# [CV 2/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=500, subsample=0.8;, score=-2401415281.968 total time=   6.0s
# [CV 3/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=500, subsample=0.8;, score=-2327520610.938 total time=   6.0s
# [CV 2/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=5, n_estimators=1000, subsample=1.0;, score=-2505340769.637 total time=  23.4s
# [CV 4/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=500, subsample=0.8;, score=-2499464961.097 total time=   6.0s
# [CV 5/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=500, subsample=0.8;, score=-2549406762.745 total time=   5.9s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=5, n_estimators=1000, subsample=1.0;, score=-2436559658.761 total time=  23.2s
# [CV 1/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=500, subsample=1.0;, score=-2703182158.733 total time=   7.2s
# [CV 2/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=500, subsample=1.0;, score=-2365087653.374 total time=   7.5s
# [CV 3/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=500, subsample=1.0;, score=-2337071318.959 total time=   7.8s
# [CV 5/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=500, subsample=1.0;, score=-2661041589.651 total time=   7.9s
# [CV 4/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=500, subsample=1.0;, score=-2557034640.152 total time=   7.9s
# [CV 4/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=5, n_estimators=1000, subsample=1.0;, score=-2595780150.993 total time=  24.2s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=5, n_estimators=1000, subsample=1.0;, score=-2598636872.018 total time=  24.0s
# [CV 1/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=1000, subsample=0.8;, score=-2528885407.807 total time=  12.6s
# [CV 2/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=1000, subsample=0.8;, score=-2355931842.881 total time=  12.5s
# [CV 3/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=1000, subsample=0.8;, score=-2202101601.183 total time=  12.4s
# [CV 4/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=1000, subsample=0.8;, score=-2378318907.106 total time=  11.9s
# [CV 5/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=1000, subsample=0.8;, score=-2431958779.513 total time=  11.5s
# [CV 1/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=5, n_estimators=500, subsample=0.8;, score=-2653709542.877 total time=   5.6s
# [CV 1/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=1000, subsample=1.0;, score=-2659316486.399 total time=  13.5s
# [CV 2/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=5, n_estimators=500, subsample=0.8;, score=-2442355861.089 total time=   5.5s
# [CV 2/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=1000, subsample=1.0;, score=-2300656946.341 total time=  13.4s
# [CV 3/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=5, n_estimators=500, subsample=0.8;, score=-2369377989.125 total time=   5.5s
# [CV 3/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=1000, subsample=1.0;, score=-2253135916.641 total time=  13.3s
# [CV 4/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=5, n_estimators=500, subsample=0.8;, score=-2478870497.957 total time=   5.5s
# [CV 4/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=1000, subsample=1.0;, score=-2443053248.841 total time=  13.3s
# [CV 5/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=5, n_estimators=500, subsample=0.8;, score=-2512347831.362 total time=   5.5s
# [CV 5/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=1000, subsample=1.0;, score=-2580310485.963 total time=  13.3s
# [CV 1/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=5, n_estimators=500, subsample=1.0;, score=-2640224959.265 total time=   6.6s
# [CV 2/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=5, n_estimators=500, subsample=1.0;, score=-2389025053.305 total time=   6.7s
# [CV 3/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=5, n_estimators=500, subsample=1.0;, score=-2373200225.846 total time=   7.0s
# [CV 4/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=5, n_estimators=500, subsample=1.0;, score=-2542996223.298 total time=   7.1s
# [CV 5/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=5, n_estimators=500, subsample=1.0;, score=-2561898945.960 total time=   7.3s
# [CV 1/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=5, n_estimators=1000, subsample=0.8;, score=-2527577461.593 total time=  12.4s
# [CV 2/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=5, n_estimators=1000, subsample=0.8;, score=-2386481164.689 total time=  12.4s
# [CV 3/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=5, n_estimators=1000, subsample=0.8;, score=-2239515671.169 total time=  12.7s
# [CV 4/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=5, n_estimators=1000, subsample=0.8;, score=-2357138151.044 total time=  12.6s
# [CV 5/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=5, n_estimators=1000, subsample=0.8;, score=-2383967225.339 total time=  12.5s
# [CV 2/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=5, n_estimators=1000, subsample=1.0;, score=-2346362138.952 total time=  14.1s
# [CV 1/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=5, n_estimators=1000, subsample=1.0;, score=-2562782611.263 total time=  14.4s
# [CV 3/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=5, n_estimators=1000, subsample=1.0;, score=-2268264947.979 total time=  14.4s
# [CV 1/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=500, subsample=0.8;, score=-2501259141.256 total time=   9.6s
# [CV 2/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=500, subsample=0.8;, score=-2398695937.449 total time=   9.7s
# [CV 3/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=500, subsample=0.8;, score=-2114042209.311 total time=   9.6s
# [CV 4/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=5, n_estimators=1000, subsample=1.0;, score=-2428869557.457 total time=  14.2s
# [CV 5/5] END learning_rate=0.1, max_depth=3, min_samples_leaf=5, n_estimators=1000, subsample=1.0;, score=-2499730727.969 total time=  14.3s
# [CV 4/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=500, subsample=0.8;, score=-2343327130.312 total time=   9.7s
# [CV 5/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=500, subsample=0.8;, score=-2239845724.310 total time=   9.7s
# [CV 1/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=500, subsample=1.0;, score=-2609525679.529 total time=  12.4s
# [CV 2/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=500, subsample=1.0;, score=-2338765061.703 total time=  12.3s
# [CV 3/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=500, subsample=1.0;, score=-2175652615.616 total time=  12.3s
# [CV 4/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=500, subsample=1.0;, score=-2388446922.963 total time=  12.3s
# [CV 5/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=500, subsample=1.0;, score=-2311277242.454 total time=  12.1s
# [CV 1/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=1000, subsample=0.8;, score=-2493605946.948 total time=  19.6s
# [CV 2/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=1000, subsample=0.8;, score=-2366203317.716 total time=  19.4s
# [CV 3/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=1000, subsample=0.8;, score=-2083294037.688 total time=  19.7s
# [CV 4/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=1000, subsample=0.8;, score=-2315389344.840 total time=  18.8s
# [CV 5/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=1000, subsample=0.8;, score=-2220271369.819 total time=  18.8s
# [CV 1/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=5, n_estimators=500, subsample=0.8;, score=-2464956941.428 total time=   9.5s
# [CV 1/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=1000, subsample=1.0;, score=-2639690493.551 total time=  22.7s
# [CV 2/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=1000, subsample=1.0;, score=-2353697008.895 total time=  22.8s
# [CV 3/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=1000, subsample=1.0;, score=-2153086117.387 total time=  23.0s
# [CV 2/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=5, n_estimators=500, subsample=0.8;, score=-2335209425.997 total time=   9.6s
# [CV 3/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=5, n_estimators=500, subsample=0.8;, score=-2106098869.776 total time=   9.9s
# [CV 4/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=5, n_estimators=500, subsample=0.8;, score=-2269104093.603 total time=  10.1s
# [CV 4/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=1000, subsample=1.0;, score=-2386954810.387 total time=  23.6s
# [CV 5/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=5, n_estimators=500, subsample=0.8;, score=-2288186726.416 total time=  10.3s
# [CV 5/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=1000, subsample=1.0;, score=-2282058000.942 total time=  24.0s
# [CV 1/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=5, n_estimators=500, subsample=1.0;, score=-2475546977.757 total time=  12.4s
# [CV 2/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=5, n_estimators=500, subsample=1.0;, score=-2341178059.858 total time=  12.5s
# [CV 3/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=5, n_estimators=500, subsample=1.0;, score=-2175403743.026 total time=  12.4s
# [CV 4/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=5, n_estimators=500, subsample=1.0;, score=-2326067253.799 total time=  12.0s
# [CV 5/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=5, n_estimators=500, subsample=1.0;, score=-2299094757.478 total time=  12.4s
# [CV 2/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=5, n_estimators=1000, subsample=0.8;, score=-2326091060.727 total time=  20.2s
# [CV 1/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=5, n_estimators=1000, subsample=0.8;, score=-2475497417.290 total time=  20.4s
# [CV 3/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=5, n_estimators=1000, subsample=0.8;, score=-2079723680.011 total time=  20.6s
# [CV 4/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=5, n_estimators=1000, subsample=0.8;, score=-2263561777.495 total time=  20.2s
# [CV 5/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=5, n_estimators=1000, subsample=0.8;, score=-2277595566.119 total time=  20.4s
# [CV 1/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=5, n_estimators=1000, subsample=1.0;, score=-2470625591.599 total time=  27.7s
# [CV 2/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=5, n_estimators=1000, subsample=1.0;, score=-2373472351.172 total time=  26.7s
# [CV 3/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=5, n_estimators=1000, subsample=1.0;, score=-2211038381.394 total time= 1.2min
# [CV 4/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=5, n_estimators=1000, subsample=1.0;, score=-2298047702.165 total time= 1.4min
# [CV 5/5] END learning_rate=0.1, max_depth=5, min_samples_leaf=5, n_estimators=1000, subsample=1.0;, score=-2300818061.133 total time= 1.4min
# Saved results to gridsearch_results.pkl
# Best parameters:
# {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 5, 'n_estimators': 1000, 'subsample': 0.8}

# %% [markdown]
# ### Your grade on this assignment will be partially determined by the mean squared error on a separate holdout set. You can approximate this using the test set.

# %%
# Evaluate on test set 
y_pred = best_model.predict(X_test[indep_vars])
mse_best = mse(y_test, y_pred)

print("Test MSE:", mse_best)
# Out:
# Test MSE: 2228090793.685652
